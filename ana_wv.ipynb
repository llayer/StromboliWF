# %% [markdown]
# # Waveform analysis

# %% [markdown]
# ## 1. Load data

# %%
import signal_ana as ana
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_96python3/x86_64-centos7-gcc8-opt/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
use_wf = True
use_lpc = False
use_amp = False

# %%
# Load the signals
df = ana.load_signals('features_30.h5')

# %%
df.head()
# decimated_vlp_waveform
# Out:
#                        time  \
# 0 2019-05-27 18:16:37+00:00
# 1 2019-05-27 17:31:45+00:00
# 2 2019-05-27 17:17:41+00:00
# 3 2019-05-27 19:23:49+00:00
# 4 2019-05-27 20:41:11+00:00
#
#                                             waveform  \
# 0  [3.72132730069, -51.1812948272, -104.97754986,...
# 1  [267.286223554, 213.095748702, 156.62064283, 9...
# 2  [-150.572442193, -248.678406427, -332.00272918...
# 3  [-220.99252159, -347.395354446, -449.371607879...
# 4  [157.167620135, 286.219708967, 395.840778773, ...
#
#                                            lpc_coeff  \
# 0  [1.0, -2.18162593255, 2.49176485988, -1.993432...
# 1  [1.0, -1.91957893956, 1.75126094982, -1.247919...
# 2  [1.0, -2.23007592873, 2.50516095499, -2.071459...
# 3  [1.0, -2.32914670106, 2.68123537773, -2.092240...
# 4  [1.0, -2.38909167965, 2.78044991558, -2.351892...
#
#                                            amplitude
# 0  [0.390425590627, 0.366654576689, 0.33067666624...
# 1  [0.304056059595, 0.328030528642, 0.44393763535...
# 2  [0.661311999342, 0.584146916956, 0.42782305131...
# 3  [0.382224472907, 0.586558602969, 0.38374742891...
# 4  [0.430395495412, 0.381969445864, 0.41658439725...

# %%
# Scale to zero mean and unit variance
ana.normalize(df, 'waveform')
ana.normalize(df, 'lpc_coeff')
ana.normalize(df, 'amplitude')

# %%
# Exclude the eruption days
eruption_days = [ ('2019-07-03', '2019-07-04'), ('2019-08-28', '2019-08-29'), ('2019-08-29', '2019-08-30')]
df = ana.exclude_days(df, eruption_days)

# %%
# Select a test period
df_test = ana.test_period(df)

# %%
# Frequency of signals per day
ana.plot_freq(df)

# %%
features = ana.get_features(df, wf = use_wf, lpc=use_lpc, amp=use_amp)

# %% [markdown]
# ## 2. Clustering with Self Organizing Maps

# %% [markdown]
# ### Bayesian optimization of quantization and topological error

# %%
# Train som

size_x = 25
size_y = 25
niter = 59000 #10000
sigma = 2.2 # #0.3
learning_rate= .013 #.5
pca=False
random_seed = 2

"""
size_x = 10
size_y = 6
niter = 50000 #20000 #10000
sigma = 1.23 # #0.3
learning_rate= .04 #.5
pca=False
random_seed = 2
"""
# Out:
# '\nsize_x = 10\nsize_y = 6\nniter = 50000 #20000 #10000\nsigma = 1.23 # #0.3\nlearning_rate= .04 #.5\npca=False\nrandom_seed = 2\n'

# %%
from skopt.space import Real, Categorical, Integer

# Skopt dimensions
skopt_dims = [       
    Real(        low=1e-2, high=1,     prior='log-uniform', name='learning_rate'     ),
    Real(        low=.1,    high=5,                         name='sigma'     ),
    Real(     low=1e2,    high=1e5,   prior='log-uniform', name='niter'       )
]

# Initial parameters
init_param = {'learning_rate':0.5, 'sigma':0.3, 'niter' : 10000}

search_result = ana.optimize(skopt_dims, init_param, features, size_x, size_y,
                             num_calls=20, pca = pca, random_seed = random_seed)

# %%
som = ana.run_som(features, size_x, size_y, niter = niter, sigma=sigma, learning_rate=learning_rate, 
                  pca=pca, plot_error = False, random_seed = random_seed)

# %% [markdown]
# ### Visualize the nodes

# %%
ana.plot_waveforms(features, som, size_x, size_y )

# %%
ana.plot_dmap(features, som, size_x, size_y)

# %%
ana.plot_density(features, som, size_x, size_y )

# %% [markdown]
# ### Time evolution of the nodes

# %%
ana.feat_to_cluster(df, som, size_x, size_y, wf = use_wf, lpc = use_lpc, amp = use_amp)
ana.plot_evo(df, som, size_x, size_y)

# %% [markdown]
# ### Clustering of the nodes with kmeans

# %%
# Elbow method to check the number of clusters
ana.kmeans_som(som, features, size_x, size_y, n_clusters=4, run_elbow=True)

# %%
n_clusters = 4

# %%
clusters = ana.kmeans_som(som, features, size_x, size_y, n_clusters=n_clusters)

# %%
ana.feat_to_cluster(df, som, size_x, size_y, wf = use_wf, lpc = use_lpc, amp = use_amp)

# %%
ana.som_to_kmeans_cluster(df, clusters)

# %%
ana.plot_hist2d(df, 'cluster_som_kmeans', n_clusters)

# %% [markdown]
# ## Clustering with K-means with T-SNE visualization

# %%
tsne_x, tsne_y = ana.run_tsne(features)
df['tsne_x'] = tsne_x
df['tsne_y'] = tsne_y
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 19748 samples in 0.403s...
# [t-SNE] Computed neighbors for 19748 samples in 118.054s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19748
# [t-SNE] Computed conditional probabilities for sample 2000 / 19748
# [t-SNE] Computed conditional probabilities for sample 3000 / 19748
# [t-SNE] Computed conditional probabilities for sample 4000 / 19748
# [t-SNE] Computed conditional probabilities for sample 5000 / 19748
# [t-SNE] Computed conditional probabilities for sample 6000 / 19748
# [t-SNE] Computed conditional probabilities for sample 7000 / 19748
# [t-SNE] Computed conditional probabilities for sample 8000 / 19748
# [t-SNE] Computed conditional probabilities for sample 9000 / 19748
# [t-SNE] Computed conditional probabilities for sample 10000 / 19748
# [t-SNE] Computed conditional probabilities for sample 11000 / 19748
# [t-SNE] Computed conditional probabilities for sample 12000 / 19748
# [t-SNE] Computed conditional probabilities for sample 13000 / 19748
# [t-SNE] Computed conditional probabilities for sample 14000 / 19748
# [t-SNE] Computed conditional probabilities for sample 15000 / 19748
# [t-SNE] Computed conditional probabilities for sample 16000 / 19748
# [t-SNE] Computed conditional probabilities for sample 17000 / 19748
# [t-SNE] Computed conditional probabilities for sample 18000 / 19748
# [t-SNE] Computed conditional probabilities for sample 19000 / 19748
# [t-SNE] Computed conditional probabilities for sample 19748 / 19748
# [t-SNE] Mean sigma: 2.727439
# [t-SNE] Computed conditional probabilities in 1.611s
# [t-SNE] Iteration 50: error = 76.4597855, gradient norm = 0.0088450 (50 iterations in 10.972s)
# [t-SNE] Iteration 100: error = 83.7994843, gradient norm = 0.0023003 (50 iterations in 12.328s)
# [t-SNE] Iteration 150: error = 84.4947433, gradient norm = 0.0018769 (50 iterations in 16.616s)
# [t-SNE] Iteration 200: error = 84.6966248, gradient norm = 0.0023887 (50 iterations in 20.393s)
# [t-SNE] Iteration 250: error = 85.7770538, gradient norm = 0.0011717 (50 iterations in 24.052s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.777054
# [t-SNE] Iteration 300: error = 3.3373263, gradient norm = 0.0009701 (50 iterations in 16.965s)
# [t-SNE] Iteration 350: error = 3.0302505, gradient norm = 0.0005022 (50 iterations in 12.111s)
# [t-SNE] Iteration 400: error = 2.8506036, gradient norm = 0.0003310 (50 iterations in 11.373s)
# [t-SNE] Iteration 450: error = 2.7237234, gradient norm = 0.0002425 (50 iterations in 10.509s)
# [t-SNE] Iteration 500: error = 2.6311896, gradient norm = 0.0001838 (50 iterations in 10.348s)
# [t-SNE] Iteration 550: error = 2.5610139, gradient norm = 0.0001467 (50 iterations in 10.270s)
# [t-SNE] Iteration 600: error = 2.5072622, gradient norm = 0.0001190 (50 iterations in 10.382s)
# [t-SNE] Iteration 650: error = 2.4641640, gradient norm = 0.0000998 (50 iterations in 10.565s)
# [t-SNE] Iteration 700: error = 2.4286826, gradient norm = 0.0000856 (50 iterations in 10.737s)
# [t-SNE] Iteration 750: error = 2.3993332, gradient norm = 0.0000741 (50 iterations in 10.851s)
# [t-SNE] Iteration 800: error = 2.3744273, gradient norm = 0.0000656 (50 iterations in 10.991s)
# [t-SNE] Iteration 850: error = 2.3532734, gradient norm = 0.0000578 (50 iterations in 10.415s)
# [t-SNE] Iteration 900: error = 2.3349926, gradient norm = 0.0000518 (50 iterations in 11.072s)
# [t-SNE] Iteration 950: error = 2.3190310, gradient norm = 0.0000468 (50 iterations in 10.602s)
# [t-SNE] Iteration 1000: error = 2.3050992, gradient norm = 0.0000430 (50 iterations in 11.075s)
# [t-SNE] KL divergence after 1000 iterations: 2.305099

# %%
# Run elbow method
max_cls = 10
ana.elbow(max_cls, features)

# %%
# Run kmeans
n_cluster = 4
df['kmeans'] = ana.run_kmeans(features, n_cluster)

# %%
ana.plot_kmeans_tsne(df, 'kmeans', n_clusters)
# Out:
# r
# g
# b
# c
